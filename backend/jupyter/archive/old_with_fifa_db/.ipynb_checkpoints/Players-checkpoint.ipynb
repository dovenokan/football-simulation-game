# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re

# %%
# Suppress SettingWithCopyWarning
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# <br>

# %% [markdown]
# # Data Cleaning & Preprocessing

# %%
df_raw = pd.read_csv("players.csv")
# Out:
# C:\Users\okany\AppData\Local\Temp\ipykernel_17124\447118444.py:1: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv("players.csv")

# %%
df_raw["fifa_version"].value_counts(sort=False)
# Out:
# fifa_version
# 24.0    18350
# 23.0    18533
# 22.0    19239
# 21.0    18892
# 20.0    18483
# 19.0    18086
# 18.0    17954
# 17.0    17596
# 16.0    16706
# 15.0    16182
# Name: count, dtype: int64

# %%
df_raw
# Out:
#         player_id                                         player_url  \
# 0          231747                /player/231747/kylian-mbappe/240002
# 1          239085               /player/239085/erling-haaland/240002
# 2          192985              /player/192985/kevin-de-bruyne/240002
# 3          158023                 /player/158023/lionel-messi/240002
# 4          165153                /player/165153/karim-benzema/240002
# ...           ...                                                ...
# 180016     220806  https://sofifa.com/player/220806/ellis-redman/...
# 180017     225509  https://sofifa.com/player/225509/aaron-collins...
# 180018     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 180019     222947  https://sofifa.com/player/222947/tom-davies/15...
# 180020     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#         fifa_version  fifa_update update_as_of    short_name  \
# 0               24.0          2.0   2023-09-22     K. Mbappé
# 1               24.0          2.0   2023-09-22    E. Haaland
# 2               24.0          2.0   2023-09-22  K. De Bruyne
# 3               24.0          2.0   2023-09-22      L. Messi
# 4               24.0          2.0   2023-09-22    K. Benzema
# ...              ...          ...          ...           ...
# 180016          15.0          2.0   2014-09-18     E. Redman
# 180017          15.0          2.0   2014-09-18    A. Collins
# 180018          15.0          2.0   2014-09-18      P. Żemło
# 180019          15.0          2.0   2014-09-18     T. Davies
# 180020          15.0          2.0   2014-09-18    P. Tisdale
#
#                              long_name player_positions  overall  potential  \
# 0                 Kylian Mbappé Lottin           ST, LW       91         94
# 1                 Erling Braut Haaland               ST       91         94
# 2                      Kevin De Bruyne          CM, CAM       91         91
# 3       Lionel Andrés Messi Cuccittini          CF, CAM       90         90
# 4                        Karim Benzema           CF, ST       90         90
# ...                                ...              ...      ...        ...
# 180016                    Ellis Redman               CB       41         61
# 180017       Aaron Graham John Collins               ST       41         50
# 180018                     Piotr Żemło           LM, LB       40         50
# 180019       Thomas Christopher Davies               CB       40         49
# 180020                    Paul Tisdale          CM, CAM       40         40
#
#         ...   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk
# 0       ...  63+3  63+3  63+3  68+3  63+3  54+3  54+3  54+3  63+3  18+3
# 1       ...  63+3  63+3  63+3  62+3  60+3  62+3  62+3  62+3  60+3  19+3
# 2       ...  80+3  80+3  80+3  79+3  75+3  70+3  70+3  70+3  75+3  21+3
# 3       ...  63+3  63+3  63+3  64+3  59+3  49+3  49+3  49+3  59+3  19+3
# 4       ...  64+3  64+3  64+3  64+3  60+3  55+3  55+3  55+3  60+3  18+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 180016  ...    38    38    38    37    40    41    41    41    40    10
# 180017  ...    30    30    30    31    32    31    31    31    32    14
# 180018  ...    46    46    46    48  51-1  53-3  53-3  53-3  51-1    12
# 180019  ...    36    36    36    37    39    40    40    40    39    13
# 180020  ...    37    37    37    36    34    33    33    33    34    10
#
# [180021 rows x 109 columns]

# %%
# Leagues Allowed
fifa_version = 23
allowed_leagues = [13,53,19,31,16,10,308,68]

# %%
df = df_raw[
    (df_raw["fifa_version"] == fifa_version)
    & df_raw["league_id"].isin(allowed_leagues)
]

# %%
df
# Out:
#        player_id      short_name                       long_name  \
# 18350     231747       K. Mbappé            Kylian Mbappé Lottin
# 18351     158023        L. Messi  Lionel Andrés Messi Cuccittini
# 18352     165153      K. Benzema                   Karim Benzema
# 18353     188545  R. Lewandowski              Robert Lewandowski
# 18354     192985    K. De Bruyne                 Kevin De Bruyne
# ...          ...             ...                             ...
# 36405     265527       O. Tipton                   Oliver Tipton
# 36628     268636   D. Ciezkowski               Dorian Ciezkowski
# 36644     270567        A. Demir                      Anıl Demir
# 36654     268630        I. Price                     Isaac Price
# 36758     270672         A. Arda                        Alp Arda
#
#       player_positions  overall  potential    value_eur  wage_eur         dob  \
# 18350               ST       91         95  190500000.0  230000.0  1998-12-20
# 18351               RW       91         91   54000000.0  195000.0  1987-06-24
# 18352               CF       91         91   64000000.0  450000.0  1987-12-19
# 18353               ST       91         91   84000000.0  420000.0  1988-08-21
# 18354               CM       91         91  107500000.0  350000.0  1991-06-28
# ...                ...      ...        ...          ...       ...         ...
# 36405               CB       52         67     170000.0    2000.0  2003-09-22
# 36628               GK       51         58     100000.0     950.0  2001-03-22
# 36644               GK       51         56      70000.0    2000.0  1996-11-04
# 36654               CM       50         73     150000.0    2000.0  2003-09-26
# 36758               GK       50         54      50000.0    1000.0  1995-06-07
#
#        height_cm  ...  ldm cdm  rdm rwb  lb  lcb  cb rcb  rb  gk
# 18350        182  ...   63  63   63  67  63   54  54  54  63  18
# 18351        169  ...   63  63   63  64  59   50  50  50  59  19
# 18352        185  ...   64  64   64  64  60   55  55  55  60  18
# 18353        185  ...   66  66   66  64  61   60  60  60  61  19
# 18354        181  ...   79  79   79  79  75   69  69  69  75  21
# ...          ...  ...  ...  ..  ...  ..  ..  ...  ..  ..  ..  ..
# 36405        185  ...   49  49   49  48  49   52  52  52  49  16
# 36628        191  ...   19  19   19  17  17   19  19  19  17  50
# 36644        190  ...   19  19   19  16  16   20  20  20  16  50
# 36654        178  ...   49  49   49  48  48   48  48  48  48  16
# 36758        192  ...   22  22   22  19  19   20  20  20  19  49
#
# [4395 rows x 80 columns]

# %%
# Drop Unnecessary Columns

columns_to_drop = ["player_url", "fifa_version", "fifa_update", "update_as_of", 
                   "age", "weight_kg", "league_level", 
                   "club_loaned_from", "club_joined_date", "club_contract_valid_until_year", 
                   "nation_team_id", "nation_position", "nation_jersey_number", 
                   "weak_foot", "skill_moves", "international_reputation", 
                   "work_rate", "body_type", "real_face", "release_clause_eur", 
                   "player_tags", "player_traits", "goalkeeping_speed", 
                   "pace", "shooting" , "passing" , "dribbling", "defending", "physic"] # goalkeeping_speed

df.drop(columns=columns_to_drop, inplace=True)

# %%
# Only 1 Main Position
df['player_positions'] = df['player_positions'].str.split(',').str[0]

# %%
df.head(n=5)
# Out:
#        player_id      short_name                       long_name  \
# 18350     231747       K. Mbappé            Kylian Mbappé Lottin
# 18351     158023        L. Messi  Lionel Andrés Messi Cuccittini
# 18352     165153      K. Benzema                   Karim Benzema
# 18353     188545  R. Lewandowski              Robert Lewandowski
# 18354     192985    K. De Bruyne                 Kevin De Bruyne
#
#       player_positions  overall  potential    value_eur  wage_eur         dob  \
# 18350               ST       91         95  190500000.0  230000.0  1998-12-20
# 18351               RW       91         91   54000000.0  195000.0  1987-06-24
# 18352               CF       91         91   64000000.0  450000.0  1987-12-19
# 18353               ST       91         91   84000000.0  420000.0  1988-08-21
# 18354               CM       91         91  107500000.0  350000.0  1991-06-28
#
#        height_cm  ...   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb  \
# 18350        182  ...  63+3  63+3  63+3  67+3  63+3  54+3  54+3  54+3  63+3
# 18351        169  ...  63+3  63+3  63+3  64+3  59+3  50+3  50+3  50+3  59+3
# 18352        185  ...  64+3  64+3  64+3  64+3  60+3  55+3  55+3  55+3  60+3
# 18353        185  ...  66+3  66+3  66+3  64+3  61+3  60+3  60+3  60+3  61+3
# 18354        181  ...  79+3  79+3  79+3  79+3  75+3  69+3  69+3  69+3  75+3
#
#          gk
# 18350  18+3
# 18351  19+3
# 18352  18+3
# 18353  19+3
# 18354  21+3
#
# [5 rows x 80 columns]

# %%
sns.histplot(data=df.overall, kde=True)
# Out:
# C:\Users\okany\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='overall', ylabel='Count'>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %%
position_prefixes = ['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam',
                         'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 
                         'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk']

# %%
# 93+3 is not good data 
def clean_position_ratings(rating):
    rating = rating.replace("-" , "+")
    cleaned_value = re.sub(r'\+\d+', '', rating)
    numeric_value = pd.to_numeric(cleaned_value, errors='coerce', downcast='integer')
    return pd.to_numeric(numeric_value, errors='coerce').astype('int64')

df[position_prefixes] = df[position_prefixes].applymap(clean_position_ratings)
# Out:
# C:\Users\okany\AppData\Local\Temp\ipykernel_17124\1666143454.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[position_prefixes] = df[position_prefixes].applymap(clean_position_ratings)

# %%
float64_columns = df.select_dtypes(include='float64').columns
df[float64_columns] = df[float64_columns].astype('int64', errors="ignore")

# %%
# Fix some problems with your own hands

df.mentality_composure = df.mentality_composure.apply(int)
df.club_team_id = df.club_team_id.apply(int)
df.league_id = df.league_id.apply(int)
df.club_jersey_number = df.club_jersey_number.apply(int)
df.loc[df.player_id == 120533, 'value_eur'] = 800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4395 entries, 18350 to 36758
# Data columns (total 80 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    4395 non-null   int64
#  1   short_name                   4395 non-null   object
#  2   long_name                    4395 non-null   object
#  3   player_positions             4395 non-null   object
#  4   overall                      4395 non-null   int64
#  5   potential                    4395 non-null   int64
#  6   value_eur                    4393 non-null   float64
#  7   wage_eur                     4395 non-null   float64
#  8   dob                          4395 non-null   object
#  9   height_cm                    4395 non-null   int64
#  10  club_team_id                 4395 non-null   int64
#  11  club_name                    4395 non-null   object
#  12  league_id                    4395 non-null   int64
#  13  league_name                  4395 non-null   object
#  14  club_position                4395 non-null   object
#  15  club_jersey_number           4395 non-null   int64
#  16  nationality_id               4395 non-null   int64
#  17  nationality_name             4395 non-null   object
#  18  preferred_foot               4395 non-null   object
#  19  attacking_crossing           4395 non-null   int64
#  20  attacking_finishing          4395 non-null   int64
#  21  attacking_heading_accuracy   4395 non-null   int64
#  22  attacking_short_passing      4395 non-null   int64
#  23  attacking_volleys            4395 non-null   int64
#  24  skill_dribbling              4395 non-null   int64
#  25  skill_curve                  4395 non-null   int64
#  26  skill_fk_accuracy            4395 non-null   int64
#  27  skill_long_passing           4395 non-null   int64
#  28  skill_ball_control           4395 non-null   int64
#  29  movement_acceleration        4395 non-null   int64
#  30  movement_sprint_speed        4395 non-null   int64
#  31  movement_agility             4395 non-null   int64
#  32  movement_reactions           4395 non-null   int64
#  33  movement_balance             4395 non-null   int64
#  34  power_shot_power             4395 non-null   int64
#  35  power_jumping                4395 non-null   int64
#  36  power_stamina                4395 non-null   int64
#  37  power_strength               4395 non-null   int64
#  38  power_long_shots             4395 non-null   int64
#  39  mentality_aggression         4395 non-null   int64
#  40  mentality_interceptions      4395 non-null   int64
#  41  mentality_positioning        4395 non-null   int64
#  42  mentality_vision             4395 non-null   int64
#  43  mentality_penalties          4395 non-null   int64
#  44  mentality_composure          4395 non-null   int64
#  45  defending_marking_awareness  4395 non-null   int64
#  46  defending_standing_tackle    4395 non-null   int64
#  47  defending_sliding_tackle     4395 non-null   int64
#  48  goalkeeping_diving           4395 non-null   int64
#  49  goalkeeping_handling         4395 non-null   int64
#  50  goalkeeping_kicking          4395 non-null   int64
#  51  goalkeeping_positioning      4395 non-null   int64
#  52  goalkeeping_reflexes         4395 non-null   int64
#  53  ls                           4395 non-null   int64
#  54  st                           4395 non-null   int64
#  55  rs                           4395 non-null   int64
#  56  lw                           4395 non-null   int64
#  57  lf                           4395 non-null   int64
#  58  cf                           4395 non-null   int64
#  59  rf                           4395 non-null   int64
#  60  rw                           4395 non-null   int64
#  61  lam                          4395 non-null   int64
#  62  cam                          4395 non-null   int64
#  63  ram                          4395 non-null   int64
#  64  lm                           4395 non-null   int64
#  65  lcm                          4395 non-null   int64
#  66  cm                           4395 non-null   int64
#  67  rcm                          4395 non-null   int64
#  68  rm                           4395 non-null   int64
#  69  lwb                          4395 non-null   int64
#  70  ldm                          4395 non-null   int64
#  71  cdm                          4395 non-null   int64
#  72  rdm                          4395 non-null   int64
#  73  rwb                          4395 non-null   int64
#  74  lb                           4395 non-null   int64
#  75  lcb                          4395 non-null   int64
#  76  cb                           4395 non-null   int64
#  77  rcb                          4395 non-null   int64
#  78  rb                           4395 non-null   int64
#  79  gk                           4395 non-null   int64
# dtypes: float64(2), int64(69), object(9)
# memory usage: 2.7+ MB

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %%
# df.isnull().sum().sort_values(ascending=True)
# df[df.value_eur.isna()]

# %%
x = df.loc[df.player_id == 209889, :]
# for c, value in x.iteritems():
#     print(c, ":", value)
x.lw
# Out:
# 18612    83
# Name: lw, dtype: int64

# %%
# df["player_positions"].value_counts()
# df["nationality_name"].value_counts()

# %%
df.to_csv("pdb_23.csv", index=False)

# %%
# import pandas as pd
# import sqlite3

# # Read CSV data into a DataFrame
# df = pd.read_csv('sb1.csv')

# # SQLite database file
# db_file = 'f24.db'

# # Establish connection to SQLite database
# conn = sqlite3.connect(db_file)

# # Write DataFrame to SQLite database
# df.to_sql('players', conn, if_exists='replace', index=False)

# # Close the connection
# conn.close()

# print("Data has been successfully written to SQLite database.")

# %%
# from supabase_py import create_client

# # Replace 'your-supabase-url' and 'your-api-key' with your actual Supabase URL and API key
# supabase_url = 'https://wjfnkzlgcpggflpddzgh.supabase.co'
# supabase_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6IndqZm5remxnY3BnZ2ZscGRkemdoIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTAwNzI1OTMsImV4cCI6MjAyNTY0ODU5M30.0XrnBJrIZU1eqWeeBqn62GcDWJkt32JkOsABGEjhLoU'

# # Initialize Supabase client
# supabase = create_client(supabase_url, supabase_key)

# %%
# json_data = df.to_json(orient='records')

# # Replace 'table_name' with the name of your Supabase table
# table_name = 'atest1'

# # Insert data into Supabase table
# query = supabase.table(table_name).insert(df.loc[0].to_json(orient='records'))
# response = query.execute()

# # Response
# if response.get('error') is None:
#     print("Data uploaded successfully!")
# else:
#     print("Error:", response.get('error'))

# %% [markdown]
# <br>
