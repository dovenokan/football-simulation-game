# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import warnings

# %%
import warnings
from pandas.errors import SettingWithCopyWarning
warnings.simplefilter(action='ignore', category=(SettingWithCopyWarning))
warnings.simplefilter(action='ignore', category=(FutureWarning))

# %%
pdf = pd.read_csv("players_db/fm23/platinum22_fm23data.csv")
udf = pd.read_csv("players_db/fm23/fm23db_processed.csv")

# %%
df = pd.merge(pdf, udf, how='inner', left_on='Name', right_on='Name')

# %%
positions = ['GK','WBR','DR','DC','DL','WBL','DM','MC','MR','AMC','ML','AMR','ST','AML']
df = df[["Name", "Best_Pos"] + positions]

# %% [markdown]
# <br><br><br>

# %%
players_df = pd.read_csv("players_db/fm23/fm23db_processed.csv").sort_values("tpr", ascending=False)
team_df = pd.read_csv("players_db/fm23/team_ratings.csv").sort_values("tpr", ascending=False)

# %%
team_df[["Club","tpr"]].head(n=10)
# Out:
#                    Club  tpr
# 0             FC Bayern   92
# 3       Manchester City   92
# 6           Real Madrid   88
# 20       Internazionale   88
# 51  Paris Saint-Germain   88
# 70                Lazio   88
# 1          FC Barcelona   88
# 2             Liverpool   88
# 26             AC Milan   88
# 9              Juventus   85

# %%
players_df[["Name","tpr","tpr_without_shifting"]].head(n=1)
# Out:
#            Name  tpr  tpr_without_shifting
# 3  Manuel Neuer   95                  94.0

# %%
players_df.query("Club == 'Lazio'").sort_values(by="tpr",ascending=False)[["Name","tpr","tpr_without_shifting"]]
# Out:
#                          Name  tpr  tpr_without_shifting
# 1343  Sergej Milinković-Savić   89                  90.0
# 1350            Ciro Immobile   87                  85.0
# 1361             Luis Alberto   87                  88.0
# 1365                    Pedro   86                  89.0
# 1392            Matías Vecino   85                  86.0
# 1487          Mattia Zaccagni   84                  87.0
# 1523                   Patric   83                  86.0
# 1513               Toma Bašić   82                  83.0
# 1657           Danilo Cataldi   82                  83.0
# 1460             Adam Marušić   81                  86.0
# 1464              Ştefan Radu   81                  85.0
# 1444          Felipe Anderson   81                  83.0
# 1374        Alessio Romagnoli   81                  83.0
# 1485             Elseid Hysaj   80                  84.0
# 1718            Ivan Provedel   80                  78.0
# 1517           Marcos Antonio   80                  81.0
# 1442           Manuel Lazzari   80                  84.0
# 1855               Mario Gila   80                  82.0
# 1732            Nicolò Casale   78                  80.0
# 1772       Matteo Cancellieri   77                  78.0
# 1540           Luís Maximiano   77                  75.0
# 1547            Mohamed Fares   77                  84.0
# 1760              Luka Romero   74                  75.0
# 1946            Marco Bertini   74                  74.0
# 1744      Dimitrije Kamenović   72                  74.0
# 1851          Marius Adamonis   72                  70.0
# 1921          Romano Floriani   71                  72.0
# 2052           Antonio Troise   69                  69.0
# 1997            Andrea Marino   68                  68.0
# 1951           Valerio Crespi   66                  63.0
# 1968           Filippo Bedini   66                  68.0
# 1906           Giordano Rossi   63                  63.0
# 1969          Luca Napolitano   62                  60.0
# 2047           Federico Magro   62                  59.0
# 1950       Simone Castigliani   62                  61.0
# 2471             Jacopo Sardo   60                  59.0
# 1893     Fabio Andrea Ruggeri   60                  60.0
# 1918        Larsson Coulibaly   60                  59.0
# 2389            Filip Jurczak   60                  60.0
# 2442             Enzo Adeagbo   60                  60.0
# 2039            Diego Brasili   59                  56.0
# 2518   Edoardo Della Salandra   59                  56.0
# 1910               Robin Kane   59                  59.0
# 1917        Valerio Marinacci   59                  59.0
# 2043        Alessandro Milani   58                  58.0
# 1923          Massil Adjaoudi   57                  56.0
# 2460       Ranjan Neelakandan   57                  57.0
# 2054    Marco Muhammad Schuan   57                  57.0
# 2318      Gabriele Migliorati   56                  50.0
# 2485        Lorenzo Di Biagio   56                  53.0
# 2367        Daniele Quaresima   55                  54.0
# 2493           Simone Cantoni   55                  52.0
# 1964        Michele Bigonzoni   55                  54.0
# 2510        Damiano Giranelli   55                  55.0
# 2056        Gianluca Petrucci   54                  55.0
# 2055             Andrea Rossi   54                  52.0
# 2370           Giovanni Morsa   53                  52.0
# 2320         Jordan Akwasingi   53                  52.0
# 2508         Giorgio Polidori   53                  50.0
# 2509         Leon Di Venanzio   52                  51.0

# %% [markdown]
# <br><br><br><br><br><br><br><br>
# <h1 style="color:aqua;background:blue;">Position x Position</h1>

# %%
positions = ['GK','WBR','DR','DC','DL','WBL','DM','MC','MR','AMC','ML','AMR','ST','AML']

# %%
pf = pd.read_csv("players_db/fm23/platinum22_fm23data.csv")
fm_df = pd.read_csv("players_db/fm23/fm23db_processed.csv")
df = pd.merge(pf, fm_df, how='inner', left_on='Name', right_on='Name')

# %%
xdf = df
x_arr = []
x_dict = {}

for p1 in positions:
    mean_first_pos = xdf.query(f"Best_Pos == '{p1}'")[positions].mean()
    nested_dict = {}
    for p2 in positions:
        mean_second_pos = xdf.query(f"Best_Pos == '{p2}'")[positions].mean()
        max_means = mean_first_pos.combine(mean_second_pos, max)
        nested_dict[p2] = max_means.to_dict()
    x_dict[p1] = nested_dict

# %%
formula_df = pd.DataFrame(index=positions, columns=positions)

for p1 in positions:
    for p2 in positions:
        formula_df.loc[p1, p2] = round(x_dict[p2][p2][p1], 2)

# %%
p1 = "MC"

mean_first_pos = df.query(f"Best_Pos == '{p1}'")[positions].mean()
mean_first_pos
# Out:
# GK      1.040948
# WBR     2.353448
# DR      2.286638
# DC      2.661638
# DL      1.862069
# WBL     1.838362
# DM     14.614224
# MC     19.644397
# MR      5.771552
# AMC    11.771552
# ML      5.306034
# AMR     5.101293
# ST      2.075431
# AML     4.808190
# dtype: float64

# %%
formula_df
# Out:
#         GK    WBR     DR     DC     DL    WBL     DM     MC     MR    AMC  \
# GK   19.12    1.0   1.09   1.04   1.09    1.0    1.0   1.04    1.0   1.18
# WBR   1.14  19.67  15.97   2.35    2.5    2.0   2.55   2.35  14.07   1.31
# DR    1.22  17.54  19.13   5.73   3.15    2.0   3.57   2.29  12.19   1.08
# DC    1.26   3.04   9.15  19.75   8.58   3.44   8.59   2.66    2.4    1.0
# DL    1.13   9.04   8.81   4.84  19.02  17.94   2.22   1.86   5.26    1.3
# WBL   1.06   8.96   6.73   2.22  16.05  19.62   1.91   1.84   4.88   1.31
# DM    1.15    3.5   4.29    6.1   3.55   3.75  19.36  14.61    3.0   5.36
# MC    1.33   4.46   3.72   2.77   3.12   6.94  17.06  19.64   6.07  15.31
# MR    1.23  13.46   8.68   1.21   2.04   2.19   3.48   5.77  17.79   7.09
# AMC   1.38   3.21   1.64   1.19   1.57   3.06   4.87  11.77   6.17   19.5
# ML    1.26   6.04   3.25   1.18  10.21  14.19   2.61   5.31   7.81   7.18
# AMR   1.27  10.71   4.59   1.18   1.82   3.31   2.03    5.1  13.36  10.61
# ST    1.27   2.38   1.21   1.23   1.27   1.44   1.24   2.08   3.74    8.2
# AML   1.33   5.58   2.08   1.12   6.38   10.5   1.79   4.81    7.0  10.26
#
#         ML    AMR     ST    AML
# GK     1.0   1.07   1.13    1.0
# WBR   4.03   3.24   1.22   2.32
# DR    3.19   2.26   1.15   1.67
# DC    1.83   1.38   1.25   1.04
# DL    9.14   2.09    1.0   1.78
# WBL  10.51   2.68   1.04   2.55
# DM    2.97   1.98   1.23   1.76
# MC    8.02   6.44   1.89    6.5
# MR   10.46  11.39   2.78    9.6
# AMC   10.4  12.42   7.41  13.28
# ML   17.35   9.22   2.71  11.25
# AMR  10.32   18.1   7.51  15.37
# ST    5.11  10.58  19.35  12.37
# AML   14.6  14.35   7.75  18.51

# %%
formula_df.to_csv('players_db/fm23/Position_Position_Weights.csv', index=True)

# %% [markdown]
# <br><br><br><br><br><br><br><br>
# <h1 style="color:aqua;background:black;"> Attribute x Position</h1>

# %%
plat_df = pd.read_csv("players_db/fm23/platinum22_fm23data.csv")
inside_df = pd.read_csv("players_db/fm23/fm22_players_fminside.csv")

# %%
tpr_cols = ['Aggression', 'Anticipation', 'Bravery', 'Composure', 'Concentration',
       'Decisions', 'Determination', 'Flair', 'Leadership', 'Off the Ball',
       'Positioning', 'Teamwork', 'Vision', 'Work Rate', 'Acceleration',
       'Agility', 'Balance', 'Jumping Reach', 'Natural Fitness', 'Pace', 'Stamina',
       'Strength', 'Corners', 'Crossing', 'Dribbling', 'Finishing',
       'First Touch', 'Free Kick Taking', 'Heading', 'Long Shots',
       'Long Throws', 'Marking', 'Passing', 'Penalty Taking', 'Tackling',
       'Technique']
len(tpr_cols)
# Out:
# 36

# %%
new_column_names = {
    'Aggressiion': 'Aggression',
    'Decision': 'Decisions',
    'Off The Ball': 'Off the Ball',
    'Position.1': 'Positioning',
    'Natural Fitness': 'Natural Fitness',
}
plat_df.rename(columns=new_column_names, inplace=True)

# %%
positions = ['GK', 'DL', 'DC', 'DR', 'WBL', 'WBR', 'DM', 'ML', 'MC', 'MR', 'AML', 'AMC', 'AMR', 'ST']
plat_df['Best_Position'] = plat_df[positions].idxmax(axis=1)

# %%
inside_df['Best_Position'] = inside_df['Position'].apply(lambda x: x.split(", ")[0] if isinstance(x, str) else [])
inside_df.columns = [col.replace(" ", "_") for col in inside_df.columns]
plat_df.columns = [col.replace(" ", "_") for col in plat_df.columns]
tpr_cols = [col.replace(" ", "_") for col in tpr_cols]

# %%
formula_df = pd.DataFrame(index=tpr_cols)
inside_df['tpr'] = None
plat_df = inside_df.sort_values(by="Ability", ascending=False)[:200]

for pos in positions:
    query = plat_df['Best_Position'] == pos
    top_50_players = plat_df[query].head(20)
    
    mean_values = (top_50_players[tpr_cols].sum() / top_50_players[tpr_cols].count())
    
    percentage_values = mean_values / mean_values.sum()
    sorted_percentages = percentage_values.sort_values()
    formula_df[pos] = sorted_percentages.to_dict()

    plat_df.loc[query, 'tpr'] = (plat_df[query][tpr_cols] * percentage_values).sum(axis=1)

    max_tpr = plat_df.loc[query, 'tpr'].max()
    min_tpr = plat_df.loc[query, 'tpr'].min()
    if max_tpr == min_tpr:
        min_tpr -= 1
        plat_df.loc[query, 'tpr'] = (plat_df.loc[query, 'tpr'] - min_tpr) / (max_tpr - min_tpr)

    multiplier_tpr = (94 / plat_df.loc[query, 'tpr'].max())
    plat_df.loc[query, 'tpr'] = (plat_df.loc[query, 'tpr'] * multiplier_tpr).astype(int)

plat_df["Error"] = plat_df["tpr"] - plat_df["Ability"]
plat_df["Error"].mean()
# Out:
# 5.325

# %%
plat_df.sort_values(by="tpr", ascending=False)[["Name","Ability","tpr","Best_Position","Error"]].head(n=5)
# Out:
#                 Name  Ability tpr Best_Position Error
# 0       Lionel Messi     97.0  94           AMR  -3.0
# 9             Neymar     90.0  94            ML   4.0
# 37       David Alaba     82.0  94            DL  12.0
# 19      Sergio Ramos     85.0  94            DC   9.0
# 45  Yannick Carrasco     82.0  94           WBL  12.0

# %%
formula_df["GK"] = 0
gk_attributes = [ "Aerial_Reach","Command_of_Area", "Communication","Eccentricity", "First_Touch", "Handling", "Kicking", "One_on_Ones", "Punching", "Reflexes", "Rushing_Out", "Throwing", "Passing" ]
for i in gk_attributes:
    formula_df.loc[i, "GK"] = 1 / len(gk_attributes)
formula_df = formula_df.fillna(0)

# %%
formula_df
# Out:
#                         GK        DL        DC        DR       WBL       WBR  \
# Aggression        0.000000  0.028048  0.029816  0.029955  0.022472  0.030588
# Anticipation      0.000000  0.030303  0.034821  0.030360  0.026966  0.028235
# Bravery           0.000000  0.029598  0.034714  0.029821  0.022472  0.025882
# Composure         0.000000  0.029457  0.031626  0.028876  0.030337  0.025882
# Concentration     0.000000  0.028048  0.031520  0.028471  0.026966  0.023529
# Decisions         0.000000  0.029035  0.031839  0.029686  0.029213  0.028235
# Determination     0.000000  0.031712  0.035140  0.033329  0.033708  0.032941
# Flair             0.000000  0.026638  0.022042  0.024828  0.035955  0.042353
# Leadership        0.000000  0.022833  0.033010  0.024423  0.021348  0.023529
# Off_the_Ball      0.000000  0.031149  0.020552  0.027527  0.033708  0.028235
# Positioning       0.000000  0.028189  0.034288  0.029281  0.016854  0.018824
# Teamwork          0.000000  0.031149  0.033330  0.030630  0.026966  0.018824
# Vision            0.000000  0.027343  0.026728  0.026042  0.033708  0.037647
# Work_Rate         0.000000  0.032135  0.031945  0.032789  0.030337  0.030588
# Acceleration      0.000000  0.033686  0.025876  0.033329  0.034831  0.035294
# Agility           0.000000  0.030021  0.025343  0.028741  0.033708  0.040000
# Balance           0.000000  0.030303  0.028964  0.031170  0.028090  0.023529
# Jumping_Reach     0.000000  0.022128  0.031413  0.025098  0.019101  0.009412
# Natural_Fitness   0.000000  0.031290  0.030668  0.033329  0.029213  0.037647
# Pace              0.000000  0.033827  0.028644  0.033734  0.034831  0.035294
# Stamina           0.000000  0.032558  0.030135  0.032384  0.029213  0.030588
# Strength          0.000000  0.026357  0.033649  0.029416  0.022472  0.014118
# Corners           0.000000  0.022128  0.011607  0.017676  0.033708  0.030588
# Crossing          0.000000  0.029316  0.018528  0.028741  0.031461  0.030588
# Dribbling         0.000000  0.029457  0.023320  0.027257  0.035955  0.042353
# Finishing         0.000000  0.020296  0.018102  0.019700  0.028090  0.023529
# First_Touch       0.076923  0.030303  0.027899  0.029146  0.032584  0.037647
# Free_Kick_Taking  0.000000  0.020437  0.016399  0.018756  0.034831  0.023529
# Heading           0.000000  0.022269  0.033649  0.025233  0.015730  0.011765
# Long_Shots        0.000000  0.021705  0.019487  0.022534  0.029213  0.018824
# Long_Throws       0.000000  0.023538  0.018848  0.022264  0.008989  0.021176
# Marking           0.000000  0.027202  0.033649  0.027527  0.012360  0.014118
# Passing           0.076923  0.028894  0.030242  0.029281  0.033708  0.035294
# Penalty_Taking    0.000000  0.019450  0.019913  0.018756  0.032584  0.023529
# Tackling          0.000000  0.029035  0.034288  0.030900  0.011236  0.025882
# Technique         0.000000  0.030162  0.028006  0.029011  0.037079  0.040000
# Aerial_Reach      0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# Command_of_Area   0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# Communication     0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# Eccentricity      0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# Handling          0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# Kicking           0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# One_on_Ones       0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# Punching          0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# Reflexes          0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# Rushing_Out       0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
# Throwing          0.076923  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                         DM        ML        MC        MR       AML       AMC  \
# Aggression        0.027013  0.027047  0.025880  0.025847  0.022311  0.024658
# Anticipation      0.032831  0.032164  0.030952  0.031343  0.030790  0.031507
# Bravery           0.027844  0.026316  0.028468  0.025104  0.028112  0.028082
# Composure         0.032000  0.031433  0.029710  0.030154  0.029005  0.034932
# Concentration     0.029610  0.023392  0.027433  0.026441  0.026328  0.027397
# Decisions         0.031169  0.029240  0.030435  0.027629  0.027220  0.032192
# Determination     0.030857  0.028509  0.031988  0.030749  0.034360  0.030137
# Flair             0.025766  0.035088  0.033126  0.033720  0.037929  0.028767
# Leadership        0.025558  0.019737  0.026501  0.019756  0.026328  0.023288
# Off_the_Ball      0.027948  0.036550  0.031159  0.034759  0.033467  0.034247
# Positioning       0.029610  0.010234  0.021636  0.018122  0.012494  0.019178
# Teamwork          0.034494  0.022661  0.031988  0.028669  0.027220  0.030822
# Vision            0.031169  0.029971  0.033954  0.031046  0.029005  0.033562
# Work_Rate         0.032416  0.025585  0.031677  0.031640  0.029451  0.029452
# Acceleration      0.026701  0.034357  0.028157  0.036393  0.036591  0.028767
# Agility           0.026597  0.032164  0.030331  0.035354  0.035252  0.026712
# Balance           0.028883  0.031433  0.028778  0.028372  0.028559  0.031507
# Jumping_Reach     0.022857  0.023392  0.018841  0.021539  0.020527  0.024658
# Natural_Fitness   0.031584  0.027047  0.031781  0.033571  0.035252  0.030137
# Pace              0.027325  0.034357  0.027536  0.036393  0.034806  0.029452
# Stamina           0.032519  0.029971  0.031159  0.031640  0.031682  0.030822
# Strength          0.027117  0.027778  0.023188  0.023470  0.024543  0.026712
# Corners           0.022130  0.027047  0.026915  0.025104  0.023204  0.017808
# Crossing          0.026286  0.029971  0.028882  0.030749  0.027666  0.026027
# Dribbling         0.027221  0.032164  0.031470  0.034908  0.035252  0.031507
# Finishing         0.022753  0.032164  0.027226  0.031046  0.032575  0.034932
# First_Touch       0.032208  0.031433  0.034472  0.031937  0.034806  0.033562
# Free_Kick_Taking  0.022130  0.030702  0.027226  0.024213  0.027220  0.023973
# Heading           0.021299  0.027047  0.018427  0.019905  0.020973  0.025342
# Long_Shots        0.026182  0.030702  0.028882  0.029412  0.029451  0.028082
# Long_Throws       0.014338  0.016813  0.008903  0.013518  0.009817  0.011644
# Marking           0.024104  0.009503  0.017081  0.013220  0.008925  0.014384
# Passing           0.033662  0.030702  0.033954  0.030154  0.031236  0.032192
# Penalty_Taking    0.025662  0.035819  0.027226  0.024064  0.030344  0.030822
# Tackling          0.028779  0.013158  0.020186  0.016340  0.011602  0.017808
# Technique         0.031377  0.034357  0.034472  0.033720  0.035698  0.034932
# Aerial_Reach      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Command_of_Area   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Communication     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Eccentricity      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Handling          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Kicking           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# One_on_Ones       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Punching          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Reflexes          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Rushing_Out       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Throwing          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                        AMR        ST
# Aggression        0.024424  0.027769
# Anticipation      0.032601  0.033765
# Bravery           0.025486  0.030504
# Composure         0.031008  0.031976
# Concentration     0.027185  0.028716
# Decisions         0.031114  0.030083
# Determination     0.033450  0.035658
# Flair             0.035043  0.030293
# Leadership        0.023362  0.026612
# Off_the_Ball      0.034406  0.034396
# Positioning       0.016247  0.014936
# Teamwork          0.027503  0.031451
# Vision            0.031963  0.027453
# Work_Rate         0.028141  0.030714
# Acceleration      0.033132  0.029873
# Agility           0.031963  0.027979
# Balance           0.031645  0.033133
# Jumping_Reach     0.019752  0.028085
# Natural_Fitness   0.031326  0.032502
# Pace              0.031751  0.031661
# Stamina           0.029415  0.030188
# Strength          0.024530  0.031135
# Corners           0.023787  0.012412
# Crossing          0.028034  0.021142
# Dribbling         0.033875  0.028295
# Finishing         0.032707  0.036079
# First_Touch       0.033556  0.032397
# Free_Kick_Taking  0.026017  0.021458
# Heading           0.022937  0.031030
# Long_Shots        0.028034  0.027138
# Long_Throws       0.010513  0.009256
# Marking           0.012318  0.011781
# Passing           0.031645  0.028190
# Penalty_Taking    0.031220  0.033344
# Tackling          0.014654  0.016619
# Technique         0.035255  0.031976
# Aerial_Reach      0.000000  0.000000
# Command_of_Area   0.000000  0.000000
# Communication     0.000000  0.000000
# Eccentricity      0.000000  0.000000
# Handling          0.000000  0.000000
# Kicking           0.000000  0.000000
# One_on_Ones       0.000000  0.000000
# Punching          0.000000  0.000000
# Reflexes          0.000000  0.000000
# Rushing_Out       0.000000  0.000000
# Throwing          0.000000  0.000000

# %%
formula_df.sum()
# Out:
# GK     1.0
# DL     1.0
# DC     1.0
# DR     1.0
# WBL    1.0
# WBR    1.0
# DM     1.0
# ML     1.0
# MC     1.0
# MR     1.0
# AML    1.0
# AMC    1.0
# AMR    1.0
# ST     1.0
# dtype: float64

# %%
# # Shifting Positions positions=non_gk_attributes
# for pos in positions:
#     bottom_7 = formula_df[pos].sort_values(ascending=False)[-18:-11]
#     top_7 = formula_df[pos].sort_values(ascending=False)[0:7]
#     formula_df.loc[bottom_7.index, pos] = 0
#     formula_df.loc[top_7.index, pos] = list(np.array(bottom_7) + np.array(top_7))

# %%
# formula_df.sort_values(by="Long_Shots",axis=1)

# %%
formula_df.to_csv('players_db/fm23/Attribute_Position_Weights.csv', index=True)

# %% [markdown]
# <br><br><br><br><br><br><br><br>
# <h1 style="color:white;background:purple;"> Position x Role</h1>

# %%
fm_df = pd.read_csv("players_db/fm23/fm23db_processed.csv") # !BE CAREFUL BEFORE YOU USE THIS PROCESSED DATA
fm_df["Player_Role"] = fm_df["Best_Pos"] + "_" + fm_df["Best_Role"]

# %%
plat_df = pd.read_csv("players_db/fm23/platinum22_fm23data.csv")
df = pd.merge(plat_df, fm_df, how='inner', left_on='Name', right_on='Name')
roles = list(df["Player_Role"].unique())
positions = list(df["Best_Pos"].unique())

# %%
xdf = df.copy()
x_dict = {}

for role in roles:
    mean_first_pos = xdf.query(f"Player_Role == '{role}'")[positions].mean()
    nested_dict = {}
    for pos in positions:
        mean_second_pos = xdf.query(f"Player_Role == '{role}' and Best_Pos == '{pos}'")[positions].mean()
        max_means = mean_first_pos.combine(mean_second_pos, max)
        nested_dict[pos] = max_means.to_dict()[pos]
    x_dict[role] = nested_dict

# %%
formula_df = pd.DataFrame(x_dict)

# %%
formula_df.loc[:, :]
# Out:
#      MC_Mezzala  AML_Inside Forward  ST_Poacher  ST_Advanced Forward  \
# MC    19.777778            2.833333    1.607843             1.702703
# AML    6.253968           18.000000    6.470588             8.851351
# ST     2.238095           17.833333   18.627451            18.959459
# AMR    6.793651           14.833333    6.411765             8.648649
# GK     1.000000            1.000000    1.372549             1.256757
# DC     1.000000            1.000000    1.372549             1.756757
# AMC   13.761905            9.666667    6.294118             7.283784
# DM    13.079365            1.000000    1.000000             1.256757
# DR     1.222222            1.000000    1.000000             1.148649
# DL     1.285714            1.000000    1.000000             1.000000
# MR     6.857143           10.222222    2.352941             2.567568
# WBR    1.396825            1.722222    1.000000             1.121622
# WBL    1.428571            1.500000    1.000000             1.054054
# ML     6.063492           10.166667    2.549020             2.445946
#
#      AMR_Inverted Winger  ST_Deep Lying Forward  GK_Sweeper Keeper  \
# MC              7.941520               4.400000           1.143590
# AML            15.146199               7.933333           1.184615
# ST             10.450292              19.300000           1.148718
# AMR            18.222222               6.866667           1.179487
# GK              1.000000               1.000000          19.512821
# DC              1.233918               1.000000           1.097436
# AMC            14.210526              12.266667           1.220513
# DM              2.035088               1.700000           1.061538
# DR              1.345029               1.000000           1.205128
# DL              2.134503               1.000000           1.097436
# MR             11.415205               2.966667           1.200000
# WBR             1.865497               1.000000           1.189744
# WBL             2.748538               1.000000           1.082051
# ML             10.099415               3.066667           1.174359
#
#      DC_Ball Playing Defender  AMC_Attacking Midfielder  \
# MC                   3.437209                 15.487179
# AML                  1.000000                  9.846154
# ST                   1.288372                  7.564103
# AMR                  1.097674                 10.205128
# GK                   1.000000                  1.487179
# DC                  20.000000                  1.000000
# AMC                  1.120930                 19.230769
# DM                   7.697674                  5.923077
# DR                   5.744186                  1.000000
# DL                   5.283721                  1.333333
# MR                   1.181395                  5.820513
# WBR                  2.562791                  1.000000
# WBL                  2.548837                  1.333333
# ML                   1.106977                  6.256410
#
#      MC_Deep Lying Playmaker  ...  DM_Segundo Volante  AMC_Enganche  \
# MC                 19.884615  ...               16.50          15.0
# AML                 3.865385  ...                1.00          10.2
# ST                  1.634615  ...                1.00           8.0
# AMR                 3.750000  ...                1.00          10.6
# GK                  1.000000  ...                1.00           1.0
# DC                  2.134615  ...               13.50           1.0
# AMC                12.211538  ...                3.75          19.6
# DM                 15.519231  ...               19.75           4.0
# DR                  1.403846  ...                1.00           1.0
# DL                  1.173077  ...                1.00           1.0
# MR                  4.807692  ...                1.00           3.6
# WBR                 1.711538  ...                1.00           1.0
# WBL                 1.326923  ...                1.00           1.0
# ML                  4.923077  ...                1.00           3.4
#
#      DR_No-Nonsense Full-Back  AML_Raumdeuter  DL_Inverted Wing-Back  \
# MC                        2.9             5.5                    6.5
# AML                       1.0            18.0                    1.0
# ST                        1.0            20.0                    1.0
# AMR                       1.0            13.0                    1.0
# GK                        1.0             1.0                    1.0
# DC                       19.8             1.0                   20.0
# AMC                       1.0            12.0                    1.0
# DM                        6.2             1.0                    5.5
# DR                       17.2             1.0                    8.0
# DL                        7.9             1.0                   18.0
# MR                        1.7             5.5                    1.0
# WBR                       8.1             1.0                    1.0
# WBL                       1.2             1.0                    1.0
# ML                        1.0             6.5                    1.0
#
#      AML_Wide Target Forward  ML_Defensive Winger  MR_Wide Playmaker  \
# MC                       1.0                  8.5                1.0
# AML                     19.0                 17.0               16.0
# ST                      20.0                  1.0                1.0
# AMR                     17.0                  8.5               18.0
# GK                       1.0                  1.0                1.0
# DC                       1.0                  1.0                1.0
# AMC                      1.0                 13.0                1.0
# DM                       1.0                  1.0                1.0
# DR                      12.0                  1.0               18.0
# DL                       7.0                 13.0               20.0
# MR                      15.0                  9.5               18.0
# WBR                      5.0                  1.0               18.0
# WBL                      1.0                 14.5               18.0
# ML                      15.0                 20.0               18.0
#
#      ST_False Nine  DM_Regista
# MC            10.0        19.0
# AML            1.0         5.0
# ST            18.0         1.0
# AMR           12.0         5.0
# GK             1.0         1.0
# DC             1.0         1.0
# AMC           20.0        15.0
# DM             1.0        20.0
# DR             1.0         1.0
# DL             1.0         1.0
# MR             1.0         7.0
# WBR            1.0         1.0
# WBL            1.0         1.0
# ML             1.0         7.0
#
# [14 rows x 62 columns]

# %%
selected_cols = [col for col in formula_df.columns if col.startswith("DC")]
formula_df[selected_cols]
# Out:
#      DC_Ball Playing Defender  DC_Wide Centre-Back  DC_Central Defender  \
# MC                   3.437209             1.681818             2.433526
# AML                  1.000000             1.000000             1.179191
# ST                   1.288372             1.000000             1.167630
# AMR                  1.097674             1.000000             1.248555
# GK                   1.000000             1.000000             1.109827
# DC                  20.000000            19.954545            19.439306
# AMC                  1.120930             1.000000             1.283237
# DM                   7.697674             4.727273             4.786127
# DR                   5.744186             8.954545             5.404624
# DL                   5.283721             8.772727             4.011561
# MR                   1.181395             1.000000             1.231214
# WBR                  2.562791             5.500000             1.924855
# WBL                  2.548837             3.636364             1.786127
# ML                   1.106977             1.409091             1.184971
#
#      DC_No-Nonsense Centre-Back
# MC                     1.641509
# AML                    1.452830
# ST                     1.301887
# AMR                    1.358491
# GK                     1.000000
# DC                    19.641509
# AMC                    1.245283
# DM                     4.452830
# DR                     5.396226
# DL                     4.113208
# MR                     1.301887
# WBR                    1.566038
# WBL                    1.716981
# ML                     1.396226

# %%
formula_df.to_csv('players_db/fm23/Position_Role_Weights.csv', index=True)

# %% [markdown]
# <br><br><br><br><br><br><br><br>
# <h1 style="color:white;background:green;"> Attribute x Role</h1>

# %%
inside_df['tpr'] = None
merged_df_inside = pd.merge(inside_df, fm_df, how='inner', left_on='Name', right_on='Name', suffixes=('', '_y'))
plat_df = merged_df_inside.sort_values(by="Ability", ascending=False)
x_tpr_cols = [col + "" for col in tpr_cols]
formula_df = pd.DataFrame(index=x_tpr_cols)

for role in roles:
    query = plat_df['Player_Role'] == role
    top_50_players = plat_df[query].sort_values(by="Ability", ascending=False).head(20)
    
    mean_values = (top_50_players[x_tpr_cols].sum() / top_50_players[x_tpr_cols].count())
    
    percentage_values = mean_values / mean_values.sum()
    sorted_percentages = percentage_values.sort_values()
    formula_df[role] = sorted_percentages.to_dict()

    plat_df.loc[query, 'tpr'] = (plat_df[query][x_tpr_cols] * percentage_values).sum(axis=1)

    max_tpr = plat_df.loc[query, 'tpr'].max()
    min_tpr = plat_df.loc[query, 'tpr'].min()
    if max_tpr == min_tpr:
        min_tpr -= 1
        plat_df.loc[query, 'tpr'] = (plat_df.loc[query, 'tpr'] - min_tpr) / (max_tpr - min_tpr)

    multiplier_tpr = (94 / plat_df.loc[query, 'tpr'].max())
    plat_df.loc[query, 'tpr'] = (plat_df.loc[query, 'tpr'] * multiplier_tpr).astype(int)

plat_df["Error"] = plat_df["tpr"] - plat_df["Ability"]
plat_df["Error"].mean()
# Out:
# 14.977280550774527

# %%
plat_df[["Name","tpr","Best_Pos"]].sort_values(by="tpr", ascending=False).head(n=25)
# Out:
#                     Name tpr Best_Pos
# 0           Lionel Messi  94      AMC
# 139       Kieran Tierney  94       DL
# 1008        Fidel Chaves  94      AML
# 194                 Saúl  94       MR
# 197           Iago Aspas  94      AMR
# 2393     Million Manhoef  94       MR
# 1076       Junior Sambia  94      WBR
# 1078       Mason Holgate  94       DR
# 758        Franck Ribéry  94      AML
# 165         Mikel Merino  94       MC
# 138          Dani Parejo  94       MC
# 36           David Alaba  94       DL
# 92          João Cancelo  94       DR
# 66          Luis Alberto  94       MC
# 77            João Félix  94       GK
# 73       Antonio Rüdiger  94       DC
# 955              Joaquín  94       DM
# 68      Jordan Henderson  94       DM
# 78      Andrew Robertson  94      WBL
# 57         Juan Cuadrado  94       MR
# 222          Reece James  94       DR
# 178               Felipe  94       DC
# 261        Dani Carvajal  94       DR
# 1110          André Hahn  94       MR
# 1     Robert Lewandowski  94       ST

# %%
formula_df.head()
# Out:
#                MC_Mezzala  AML_Inside Forward  ST_Poacher  \
# Aggression       0.029098            0.026672    0.026132
# Anticipation     0.028536            0.029744    0.035656
# Bravery          0.028761            0.027650    0.029501
# Composure        0.028761            0.031001    0.034611
# Concentration    0.027413            0.027929    0.030314
#
#                ST_Advanced Forward  AMR_Inverted Winger  \
# Aggression                0.024708             0.025516
# Anticipation              0.031783             0.030490
# Bravery                   0.029313             0.026922
# Composure                 0.031222             0.030057
# Concentration             0.029088             0.027571
#
#                ST_Deep Lying Forward  GK_Sweeper Keeper  \
# Aggression                  0.026370           0.027731
# Anticipation                0.031773           0.030012
# Bravery                     0.028099           0.027491
# Composure                   0.031882           0.030612
# Concentration               0.029612           0.026891
#
#                DC_Ball Playing Defender  AMC_Attacking Midfielder  \
# Aggression                     0.030576                  0.026345
# Anticipation                   0.034224                  0.030644
# Bravery                        0.033580                  0.025463
# Composure                      0.031864                  0.030754
# Concentration                  0.031327                  0.026345
#
#                MC_Deep Lying Playmaker  ...  DM_Segundo Volante  AMC_Enganche  \
# Aggression                    0.025536  ...            0.027060      0.023332
# Anticipation                  0.031063  ...            0.027060      0.030700
# Bravery                       0.027415  ...            0.030066      0.020876
# Composure                     0.032169  ...            0.030066      0.036431
# Concentration                 0.028742  ...            0.027060      0.027425
#
#                DR_No-Nonsense Full-Back  AML_Raumdeuter  \
# Aggression                     0.033056        0.025031
# Anticipation                   0.032778        0.032541
# Bravery                        0.033056        0.031289
# Composure                      0.026944        0.030038
# Concentration                  0.029722        0.032541
#
#                DL_Inverted Wing-Back  AML_Wide Target Forward  \
# Aggression                  0.029118                 0.021327
# Anticipation                0.033278                 0.030806
# Bravery                     0.030782                 0.035545
# Composure                   0.029950                 0.030806
# Concentration               0.028286                 0.033175
#
#                ML_Defensive Winger  MR_Wide Playmaker  ST_False Nine  \
# Aggression                0.030186           0.023196            NaN
# Anticipation              0.026316           0.030928            NaN
# Bravery                   0.032508           0.025773            NaN
# Composure                 0.027864           0.018041            NaN
# Concentration             0.026316           0.033505            NaN
#
#                DM_Regista
# Aggression            NaN
# Anticipation          NaN
# Bravery               NaN
# Composure             NaN
# Concentration         NaN
#
# [5 rows x 62 columns]

# %%
# Lack Columns
position_role_df = pd.read_csv("players_db/fm23/Position_Role_Weights.csv", index_col=0)
lack_data_columns = list(set(fm_df["Player_Role"].unique()) - set(formula_df.columns))
for col in lack_data_columns:
    formula_df[col] = 0
    position = col.split("_")[0]
    print(position)
# Out:
# AMR
# AMR
# DC
# WBL
# AML
# MC

# %%
lack_data_columns
# Out:
# ['AMR_Wide Target Forward',
#  'AMR_Raumdeuter',
#  'DC_Libero',
#  'WBL_Inverted Wing-Back',
#  'AML_Wing-Back',
#  'MC_Roaming Playmaker']

# %%
position_role_df.loc["AMR",:]
# Out:
# MC_Mezzala                  6.793651
# AML_Inside Forward         14.833333
# ST_Poacher                  6.411765
# ST_Advanced Forward         8.648649
# AMR_Inverted Winger        18.222222
#                              ...
# AML_Wide Target Forward    17.000000
# ML_Defensive Winger         8.500000
# MR_Wide Playmaker          18.000000
# ST_False Nine              12.000000
# DM_Regista                  5.000000
# Name: AMR, Length: 62, dtype: float64

# %%
formula_df.to_csv('players_db/fm23/Attribute_Role_Weights.csv', index=True)
